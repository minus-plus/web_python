# %% [markdown]
# <a href="https://colab.research.google.com/github/minus-plus/web_python/blob/master/notebooks/gscholar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Independent citation counter
#
# In this notebook, you can calculate the number of independent citations for all of your papers.
#
# ### What the code will do?
# For each entry in your Google Scholar profile, the code will output your independent citation count, total citation count and a link to access your independent citation counts.
#
#
# **Sample output:**
#
# > The impact of cosmic variance on simulating weak lensing surveys
# >
# > Citations: 9/15
# >
# > Link:  [http://scholar.google.com/scholar?cites=17631820148925503603&scipsc=1&q=-author:%27A%20Kannawadi%27+-author:%27R%20Mandelbaum%27+-author:%27C%20Lackner%27](http://scholar.google.com/scholar?cites=17631820148925503603&scipsc=1&q=-author:%27A%20Kannawadi%27+-author:%27R%20Mandelbaum%27+-author:%27C%20Lackner%27)
#
# The first line is the title of the paper, which has 9 independent citations and 15 total citations.
# The link takes you to the Google Scholar page with the independent citations.
#
# **Note:**
# Even if the program is unable to fetch independent citation counts, it will still output your total citations and provide a link to access your independent citations.
#
#
# ### How to use?
# In the cell below, replace `qc6CJjYAAAAJ` with your Google Scholar profile ID.
# You may also want to specify a proxy type (more details below).
# Then, run all cells.
#
# If you are not familiary with running Jupyter notebooks, you can watch an end-to-end video tutorial [here](https://www.youtube.com/watch?v=V13Fx7GesEQ)
#
# ### Troubleshooting
# If you see a `MaxTriesExceededException`, it means Google Scholar caught a whiff of your action.
# Try again later, or use a better proxy.
#
# <br>
#
# ### Enter your Google Scholar profile ID
# *unless you are Albert Einstein.*
#
# For example, if your Google Scholar profile URL is [`https://scholar.google.com/citations?user=qc6CJjYAAAAJ&hl=en`](https://scholar.google.com/citations?user=qc6CJjYAAAAJ&hl=en), then your profile ID is `qc6CJjYAAAAJ`.

# %%
# The only cell which you are expected to modify.
scholar_id = 'On_auewAAAAJ'

# `proxy_type` must be one of ScraperAPI, Luminati, FreeProxy, SingleProxy or NoProxy.
# NoProxy will give only the links to independent, not the counts.
proxy_type = 'noproxy'  # Case insensitive

# %% [markdown]
# #### More on `proxy_type`
#
# By default, the code provides only the links to page containing independent citations, and does not open the page to count them.
# Google Scholar actively blocks automated requests to its citation database.
# Continuous, repeated requests from a single IP address may lead to a ban.
# However, if you need the counts, you may be able to circumvent this by using a proxy.
# Below are a few options:
#
# - **FreeProxy**: Use continuously changing proxies for free.
#
#     This protects your IP address, but is not very effective at circumventing Google Scholar's anti-bot prevention. You might want to use other options if you are unable to reach Google Scholar.
#
#
# - **ScraperAPI** (recommended): [Create a free account](https://www.scraperapi.com/) without providing personal and payment information. Free account supports 5000 requests per month, more that sufficient to run this notebook for most researchers.
#
# - **Luminati** (untested): Similar to ScraperAPI, and is known to circumvent Google Scholar's anti-bot prevention better. No free account is available.
#
# - **SingleProxy**: Use a single proxy for all requests.
#
# - **NoProxy** (default): Using `NoProxy` will not fetch the counts by default. You can still try to fetch the counts (at your own risk) by setting `links_only` below to `False`. Use this sparingly if `FreeProxy` does not work and you don't want to create any accounts. You may also use this safely if you are already connected to a VPN.
#
#
#
#
# Read the [official scholarly documentation](https://scholarly.readthedocs.io/en/latest/quickstart.html#using-proxies) for more details.

# %%
# links_only = (proxy_type.lower() == 'noproxy')
links_only = False

# %% [markdown]
# ### Install and import the required packages.

# %%
! pip install -q scholarly
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.1/201.1 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 92.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 105.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 481.7/481.7 kB 29.7 MB/s eta 0:00:00
#   Building wheel for bibtexparser (setup.py) ... done
#   Building wheel for free-proxy (setup.py) ... done

# %%
# Suppress the cell's output since it prints a misleading traceback.
# %%capture
try:
    from scholarly import scholarly, ProxyGenerator, MaxTriesExceededException
except IndexError:
    """ Ignore the harmless IndexError occuring from a dependency"""
    pass
import time, random
from getpass import getpass
try:
    from urllib import quote  # type: ignore ; Python 2
except ImportError:
    from urllib.parse import quote  # type: ignore ; Python 3

# %%
# Utility functions
def set_proxy(proxy_type='NoProxy'):
    """Set a proxy for to scrape Google Scholar.

    Only `NoProxy`, `FreeProxy` and `ScraperAPI` have been tested.

    Parameters
    ----------
    proxy_type : str, optional
        Type of proxy to use. Case insensitive. Options are:
        `ScraperAPI`, `Luminati`, `FreeProxy`, `SingleProxy` and
        `NoProxy` (default).
    """
    if proxy_type.lower() == 'noproxy':
        print("Using no proxies!")
        return

    pg = ProxyGenerator()
    if proxy_type.lower() == 'scraperapi':
        payload = {'api_key': getpass("Enter your ScraperAPI key:"), }
        proxy_works = pg.ScraperAPI(payload['api_key'])
        if proxy_works is True:
            print("Using ScraperAPI!")
        elif proxy_works is False:
            print("ScraperAPI is not working!")
        elif proxy_works is None:
            print("Changes have not been reflected")
        else:
            print("God knows what is going on", proxy_works)
    elif proxy_type.lower() == 'luminati':
        pg.Luminati(getpass("Enter your Luminati username:"), getpass("Enter your Luminati password:"))
        print("Using Luminati!")
    elif proxy_type.lower() == 'singleproxy':
        proxy_address = getpass("Enter your proxy address:")
        pg.SingleProxy(proxy_address, proxy_address)
        print(f"Using SingleProxy: {proxy_address}")
    else:
        pg.FreeProxies()
        print("Using FreeProxy!")

    scholarly.use_proxy(pg)

def standardize_names(name):
    if not " " in name:
        return name
    try:
        parts = name.split(' ')
        firstname, lastname = parts[0], parts[-1]
        initial = firstname[0]
        return quote(f"'{initial} {lastname}'")
    except:
        # This usually happens for collaboration papers
        print(f"Cannot split '{name}' into initial and last names!")
        return quote(f"{name}")


def fill_independent_citations(publication, links_only=True):
    if not publication["source"].name == "AUTHOR_PUBLICATION_ENTRY":
        raise TypeError("Input source must be from a Google Scholar profile page")

    if not publication["filled"]:  # TODO: Don't fill once the patch comes through
        scholarly.fill(publication)

    citedby_url = publication.get("citedby_url", None)
    if citedby_url is None:
        # If there are no citations, then there is nothing to do
        publication["num_independent_citations"] = 0
        return None

    author_names = publication["bib"]["author"].split(" and ")
    independent_query = "+".join([f"-author:{standardize_names(name)}" for name in author_names])
    independent_url = citedby_url+"&hl=en&scipsc=1&q="+independent_query
    publication["independent_url"] = independent_url


    if links_only:
        return None

    try:
        search_results = scholarly.search_pubs_custom_url(independent_url)
        print("search_results", search_results)
        num_independent_citations = search_results.total_results if search_results.total_results else 0
    except Exception as err:
        num_independent_citations = -99
    publication["independent_citations"] = search_results

    publication["num_independent_citations"] = num_independent_citations

# %%
set_proxy(proxy_type)
scholar = scholarly.search_author_id(scholar_id)
scholarly.fill(scholar, sections=['basics', 'publications'])
scholar_name = scholar["name"]
print(f"Hello {scholar_name} !")
# Out:
# Using no proxies!
# Hello Ning Wang !

# %%
def get_scholar_statistics():
    print(f"Scholar: {scholar['name']}")
    print(f"Affiliation: {scholar['affiliation']}")
    print(f"Total Citations: {scholar['citedby']}")
    print("\nPublications:\n")
    for publication in scholar['publications']:
        publication = scholarly.fill(publication)
        title = publication.get('bib', {}).get('title', 'Unknown Title')
        total_citations = publication.get('num_citations', 0)
        try:
            citation_data = scholarly.citedby(publication)
        except Exception as e:
            print(f"Failed to retrieve citations for publication '{title}': {e}")
            continue
        independent_citations = []
        self_citations = []
        for citation in citation_data:
            print(citation)
            if citation.get('author_id') == scholar['scholar_id']:
                self_citations.append(citation)
            else:
                independent_citations.append(citation)
            break
        independent_to_total_ratio = (
            f"{len(independent_citations)}/{total_citations}" if total_citations > 0 else "N/A"
        )
        print(f"Title: {title}")
        print(f"  Independent Citations / Total Citations: {independent_to_total_ratio}")
        print(f"  Independent Citations: {len(independent_citations)}")
        print(f"  Self Citations: {len(self_citations)}")
        print("  List of Independent Citations:")
        for citation in independent_citations:
            print(f"    - {citation.get('bib', {}).get('title', 'Unknown Title')}")
        print("  List of Self-Citations:")
        for citation in self_citations:
            print(f"    - {citation.get('bib', {}).get('title', 'Unknown Title')}")
        print()
        break  # Limit to one publication for demonstration

get_scholar_statistics()
# Out:
# Scholar: Ning Wang
# Affiliation: Memorial Sloan Kettering
# Total Citations: 566
#
# Publications:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7c7beb435ea0>: Failed to establish a new connection: [Errno 111] Connection refused')': /session/1f94274f-74d2-44e0-873d-f27469b18f2e
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7c7beb437e20>: Failed to establish a new connection: [Errno 111] Connection refused')': /session/1f94274f-74d2-44e0-873d-f27469b18f2e
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7c7beb435450>: Failed to establish a new connection: [Errno 111] Connection refused')': /session/1f94274f-74d2-44e0-873d-f27469b18f2e
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-9fe4b7b7b539> in <cell line: 40>()
#      38         break  # Limit to one publication for demonstration
#      39
# ---> 40 get_scholar_statistics()
#
# <ipython-input-14-9fe4b7b7b539> in get_scholar_statistics()
#       9         total_citations = publication.get('num_citations', 0)
#      10         try:
# ---> 11             citation_data = scholarly.citedby(publication)
#      12         except Exception as e:
#      13             print(f"Failed to retrieve citations for publication '{title}': {e}")
#
# /usr/local/lib/python3.10/dist-packages/scholarly/_scholarly.py in citedby(self, object)
#     285
#     286         if object["num_citations"] <= 1000:
# --> 287             return PublicationParser(self.__nav).citedby(object)
#     288
#     289         self.logger.debug("Since the paper titled %s has %d citations (>1000), "
#
# /usr/local/lib/python3.10/dist-packages/scholarly/publication_parser.py in citedby(self, publication)
#     387         if not publication['filled']:
#     388             publication = self.fill(publication)
# --> 389         return _SearchScholarIterator(self.nav, publication['citedby_url'])
#     390
#     391     def bibtex(self, publication: Publication) -> str:
#
# /usr/local/lib/python3.10/dist-packages/scholarly/publication_parser.py in __init__(self, nav, url)
#      51         self._pubtype = PublicationSource.PUBLICATION_SEARCH_SNIPPET if "/scholar?" in url else PublicationSource.JOURNAL_CITATION_LIST
#      52         self._nav = nav
# ---> 53         self._load_url(url)
#      54         self.total_results = self._get_total_results()
#      55         self.pub_parser = PublicationParser(self._nav)
#
# /usr/local/lib/python3.10/dist-packages/scholarly/publication_parser.py in _load_url(self, url)
#      57     def _load_url(self, url: str):
#      58         # this is temporary until setup json file
# ---> 59         self._soup = self._nav._get_soup(url)
#      60         self._pos = 0
#      61         self._rows = self._soup.find_all('div', class_='gs_r gs_or gs_scl') + self._soup.find_all('div', class_='gsc_mpat_ttl')
#
# /usr/local/lib/python3.10/dist-packages/scholarly/_navigator.py in _get_soup(self, url)
#     237     def _get_soup(self, url: str) -> BeautifulSoup:
#     238         """Return the BeautifulSoup for a page on scholar.google.com"""
# --> 239         html = self._get_page('https://scholar.google.com{0}'.format(url))
#     240         html = html.replace(u'\xa0', u' ')
#     241         res = BeautifulSoup(html, 'html.parser')
#
# /usr/local/lib/python3.10/dist-packages/scholarly/_navigator.py in _get_page(self, pagerequest, premium)
#     130                 elif has_captcha:
#     131                     self.logger.info("Got a captcha request.")
# --> 132                     session = pm._handle_captcha2(pagerequest)
#     133                     continue  # Retry request within same session
#     134                 elif resp.status_code == 403:
#
# /usr/local/lib/python3.10/dist-packages/scholarly/_proxy_generator.py in _handle_captcha2(self, url)
#     402
#     403     def _handle_captcha2(self, url):
# --> 404         cur_host = urlparse(self._get_webdriver().current_url).hostname
#     405         for cookie in self._session.cookies:
#     406             # Only set cookies matching the current domain, cf. https://github.com/w3c/webdriver/issues/1238
#
# /usr/local/lib/python3.10/dist-packages/scholarly/_proxy_generator.py in _get_webdriver(self)
#     354
#     355         try:
# --> 356             return self._get_firefox_webdriver()
#     357         except Exception as err:
#     358             self.logger.debug("Cannot open Firefox/Geckodriver: %s", err)
#
# /usr/local/lib/python3.10/dist-packages/scholarly/_proxy_generator.py in _get_firefox_webdriver(self)
#     389         options = FirefoxOptions()
#     390         options.add_argument('--headless')
# --> 391         self._webdriver = webdriver.Firefox(options=options)
#     392         self._webdriver.get("https://scholar.google.com")  # Need to pre-load to set cookies later
#     393
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/firefox/webdriver.py in __init__(self, options, service, keep_alive)
#      69
#      70         try:
# ---> 71             super().__init__(command_executor=executor, options=options)
#      72         except Exception:
#      73             self.quit()
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/webdriver.py in __init__(self, command_executor, keep_alive, file_detector, options, locator_converter, web_element_cls, client_config)
#     239         self._authenticator_id = None
#     240         self.start_client()
# --> 241         self.start_session(capabilities)
#     242         self._fedcm = FedCM(self)
#     243
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/webdriver.py in start_session(self, capabilities)
#     327
#     328         caps = _create_caps(capabilities)
# --> 329         response = self.execute(Command.NEW_SESSION, caps)["value"]
#     330         self.session_id = response.get("sessionId")
#     331         self.caps = response.get("capabilities")
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     380                 params["sessionId"] = self.session_id
#     381
# --> 382         response = self.command_executor.execute(driver_command, params)
#     383         if response:
#     384             self.error_handler.check_response(response)
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     402         trimmed = self._trim_large_entries(params)
#     403         LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 404         return self._request(command_info[0], url, body=data)
#     405
#     406     def _request(self, method, url, body=None):
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     426
#     427         if self._client_config.keep_alive:
# --> 428             response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     429             statuscode = response.status
#     430         else:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/_request_methods.py in request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     141             )
#     142         else:
# --> 143             return self.request_encode_body(
#     144                 method, url, fields=fields, headers=headers, **urlopen_kw
#     145             )
#
# /usr/local/lib/python3.10/dist-packages/urllib3/_request_methods.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     276         extra_kw.update(urlopen_kw)
#     277
# --> 278         return self.urlopen(method, url, **extra_kw)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     441             response = conn.urlopen(method, url, **kw)
#     442         else:
# --> 443             response = conn.urlopen(method, u.request_uri, **kw)
#     444
#     445         redirect_location = redirect and response.get_redirect_location()
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787
#     788             # Make the request on the HTTPConnection object
# --> 789             response = self._make_request(
#     790                 conn,
#     791                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534         # Receive the response from the server
#     535         try:
# --> 536             response = conn.getresponse()
#     537         except (BaseSSLError, OSError) as e:
#     538             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     505
#     506         # Get the response from http.client.HTTPConnection
# --> 507         httplib_response = super().getresponse()
#     508
#     509         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# Loop over publications
if links_only:
    print("Fetching the independent citation counts has been turned off for your own good"
          " because you are not using a proxy."
          " You can turn it back on at your own risk by explicitly setting `links_only` to `False`."
          )
else:
    print("You are fetching the counts in addition to the links. The code will run slow intentionally.")

independent_citation_counts = []
import json
print(json.dumps(scholar, indent=4))
for paper in scholar["publications"]:
    if not links_only:
        # Sleep for some random time to mimic human behavior
        time.sleep(random.uniform(2, 5))

    try:
        if paper.get("num_independent_citations", -1) < 0:
            fill_independent_citations(paper, links_only=links_only)
            independent_citation_counts.append(paper.get("num_independent_citations", 0))
    except MaxTriesExceededException as err:
        print("Google Scholar is aggressively blocking us! Quitting for now.")
        print(err)
    finally:
        print("\n ------\n")
        print(paper["bib"]["title"])
        print(f"Citations: {paper.get('num_independent_citations', 'NA')}/{paper.get('num_citations')}")
        independent_url = paper.get("independent_url", None)
        if independent_url:
            print("Link: ", "http://scholar.google.com"+independent_url)

print("\n --- End of list ---")

if not links_only:
    print("Total number of independent citations = ", sum(independent_citation_counts))
# Out:
# You are fetching the counts in addition to the links. The code will run slow intentionally.
# {
#     "container_type": "Author",
#     "filled": [
#         "basics",
#         "publications"
#     ],
#     "scholar_id": "On_auewAAAAJ",
#     "source": "AUTHOR_PROFILE_PAGE",
#     "name": "Ning Wang",
#     "url_picture": "https://scholar.googleusercontent.com/citations?view_op=view_photo&user=On_auewAAAAJ&citpid=4",
#     "affiliation": "Memorial Sloan Kettering",
#     "organization": 1393959864058786198,
#     "interests": [
#         "Protein engineering",
#         "biochemistry",
#         "Mass Spectrometry"
#     ],
#     "email_domain": "@mskcc.org",
#     "citedby": 566,
#     "publications": [
#         {
#             "container_type": "Publication",
#             "source": "AUTHOR_PUBLICATION_ENTRY",
#             "bib": {
#                 "title": "Self-assembled cationic amphiphiles as antimicrobial peptides mimics: role of hydrophobicity, linkage type, and assembly state",
#                 "pub_year": "2017",
#                 "citation": "Nanomedicine: Nanotechnology, Biology and Medicine 13 (2), 343-352, 2017"
#             },
#             "filled": false,
#             "author_pub_id": "On_auewAAAAJ:IjCSPb-OGe4C",
#             "num_citations": 130,
#             "citedby_url": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3025786761997466398",
#             "cites_id": [
#                 "3025786761997466398"
#             ]
#         },
#         {
#             "container_type": "Publication",
#             "source": "AUTHOR_PUBLICATION_ENTRY",
#             "bib": {
#                 "title": "The importance of N-heterocyclic carbene basicity in organocatalysis",
#                 "pub_year": "2018",
#                 "citation": "Organic & Biomolecular Chemistry 16 (37), 6852-6866, 2018"
#             },
#             "filled": false,
#             "author_pub_id": "On_auewAAAAJ:LkGwnXOMwfcC",
#             "num_citations": 75,
#             "citedby_url": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10296876123328836370",
#             "cites_id": [
#                 "10296876123328836370"
#             ]
#         },
#         {
#             "container_type": "Publication",
#             "source": "AUTHOR_PUBLICATION_ENTRY",
#             "bib": {
#                 "title": "Magnetic nanoparticles (MNPs) covalently coated by PEO\u2013PPO\u2013PEO block copolymer for drug delivery",
#                 "pub_year": "2013",
#                 "citation": "Journal of colloid and interface science 395, 50-57, 2013"
#             },
#             "filled": false,
#             "author_pub_id": "On_auewAAAAJ:u-x6o8ySG0sC",
#             "num_citations": 74,
#             "citedby_url": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4886964103740525408",
#             "cites_id": [
#                 "4886964103740525408"
#             ]
#         },
#         {
#             "container_type": "Publication",
#             "source": "AUTHOR_PUBLICATION_ENTRY",
#             "bib": {
#                 "title": "Synthesis of polyethylenimine modified Fe3O4 nanoparticles with immobilized Cu2+ for highly efficient proteins adsorption",
#                 "pub_year": "2014",
#                 "citation": "Colloids and Surfaces A: Physicochemical and Engineering Aspects 443, 552-559, 2014"
#             },
#             "filled": false,
#             "author_pub_id": "On_auewAAAAJ:qjMakFHDy7sC",
#             "num_citations": 60,
#             "citedby_url": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=6146084551746983423",
#             "cites_id": [
#                 "6146084551746983423"
#             ]
#         },
#         {
#             "container_type": "Publication",
#             "source": "AUTHOR_PUBLICATION_ENTRY",
#             "bib": {
#                 "title": "Light, middle, and heavy rare-earth group separation: a new approach via a liquid\u2013liquid\u2013liquid three-phase system",
#                 "pub_year": "2013",
#                 "citation": "Industrial & Engineering Chemistry Research 52 (17), 5997-6008, 2013"
#             },
#             "filled": false,
#             "author_pub_id": "On_auewAAAAJ:9yKSN-GCB0IC",
#             "num_citations": 56,
#             "citedby_url": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=14986652401149326093",
#             "cites_id": [
#                 "14986652401149326093"
#             ]
#         },
#         {
#             "container_type": "Publication",
#             "source": "AUTHOR_PUBLICATION_ENTRY",
#             "bib": {
#                 "title": "Peroxidase-like activity of amino-functionalized magnetic nanoparticles and their applications in immunoassay",
#                 "pub_year": "2013",
#                 "citation": "Journal of colloid and interface science 405, 291-295, 2013"
#             },
#             "filled": false,
#             "author_pub_id": "On_auewAAAAJ:2osOgNQ5qMEC",
#             "num_citations": 51,
#             "citedby_url": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17870898425588408596",
#             "cites_id": [
#                 "17870898425588408596"
#             ]
#         },
#         {
#             "container_type": "Publication",
#             "source": "AUTHOR_PUBLICATION_ENTRY",
#             "bib": {
#                 "title": "Experimental and computational gas phase acidities of conjugate acids of triazolylidene carbenes: rationalizing subtle electronic effects",
#                 "pub_year": "2017",
#                 "citation": "Journal of the American Chemical Society 139 (42), 14917-14930, 2017"
#             },
#             "filled": false,
#             "author_pub_id": "On_auewAAAAJ:WF5omc3nYNoC",
#             "num_citations": 35,
#             "citedby_url": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7553017966423412345",
#             "cites_id": [
#                 "7553017966423412345"
#             ]
#         },
#         {
#             "container_type": "Publication",
#             "source": "AUTHOR_PUBLICATION_ENTRY",
#             "bib": {
#                 "title": "Lesion penetration and activity limit the utility of second-line injectable agents in pulmonary tuberculosis",
#                 "pub_year": "2021",
#                 "citation": "Antimicrobial agents and chemotherapy 65 (10), 10.1128/aac. 00506-21, 2021"
#             },
#             "filled": false,
#             "author_pub_id": "On_auewAAAAJ:KlAtU1dfN6UC",
#             "num_citations": 24,
#             "citedby_url": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=2238995317573690954",
#             "cites_id": [
#                 "2238995317573690954"
#             ]
#         },
#         {
#             "container_type": "Publication",
#             "source": "AUTHOR_PUBLICATION_ENTRY",
#             "bib": {
#                 "title": "Therapeutic potential of fosmanogepix (APX001) for intra-abdominal candidiasis: from lesion penetration to efficacy in a mouse model",
#                 "pub_year": "2021",
#                 "citation": "Antimicrobial agents and chemotherapy 65 (4), 10.1128/aac. 02476-20, 2021"
#             },
#             "filled": false,
#             "author_pub_id": "On_auewAAAAJ:Zph67rFs4hoC",
#             "num_citations": 18,
#             "citedby_url": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=2551194955642296580",
#             "cites_id": [
#                 "2551194955642296580"
#             ]
#         },
#         {
#             "container_type": "Publication",
#             "source": "AUTHOR_PUBLICATION_ENTRY",
#             "bib": {
#                 "title": "Gas-phase and ionic liquid experimental and computational studies of imidazole acidity and carbon dioxide capture",
#                 "pub_year": "2019",
#                 "citation": "The Journal of Organic Chemistry 84 (22), 14593-14601, 2019"
#             },
#             "filled": false,
#             "author_pub_id": "On_auewAAAAJ:roLk4NBRz8UC",
#             "num_citations": 13,
#             "citedby_url": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=6700510499976094105",
#             "cites_id": [
#                 "6700510499976094105"
#             ]
#         },
#         {
#             "container_type": "Publication",
#             "source": "AUTHOR_PUBLICATION_ENTRY",
#             "bib": {
#                 "title": "Interaction between PEO\u2013PPO\u2013PEO copolymers and a hexapeptide in aqueous solutions",
#                 "pub_year": "2012",
#                 "citation": "Langmuir 28 (3), 1725-1732, 2012"
#             },
#             "filled": false,
#             "author_pub_id": "On_auewAAAAJ:d1gkVwhDpl0C",
#             "num_citations": 10,
#             "citedby_url": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=18243606300589692500",
#             "cites_id": [
#                 "18243606300589692500"
#             ]
#         },
#         {
#             "container_type": "Publication",
#             "source": "AUTHOR_PUBLICATION_ENTRY",
#             "bib": {
#                 "title": "An optimized method for the detection and spatial distribution of aminoglycoside and vancomycin antibiotics in tissue sections by mass spectrometry imaging",
#                 "pub_year": "2021",
#                 "citation": "Journal of Mass Spectrometry 56 (3), e4708, 2021"
#             },
#             "filled": false,
#             "author_pub_id": "On_auewAAAAJ:ULOm3_A8WrAC",
#             "num_citations": 8,
#             "citedby_url": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=2312116684001385561",
#             "cites_id": [
#                 "2312116684001385561"
#             ]
#         },
#         {
#             "container_type": "Publication",
#             "source": "AUTHOR_PUBLICATION_ENTRY",
#             "bib": {
#                 "title": "On-slide heat sterilization enables mass spectrometry imaging of tissue infected with high-threat pathogens outside of biocontainment: a study directed at mycobacterium \u2026",
#                 "pub_year": "2021",
#                 "citation": "Journal of the American Society for Mass Spectrometry 32 (11), 2664-2674, 2021"
#             },
#             "filled": false,
#             "author_pub_id": "On_auewAAAAJ:YOwf2qJgpHMC",
#             "num_citations": 6,
#             "citedby_url": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10508295584586954204",
#             "cites_id": [
#                 "10508295584586954204"
#             ]
#         },
#         {
#             "container_type": "Publication",
#             "source": "AUTHOR_PUBLICATION_ENTRY",
#             "bib": {
#                 "title": "pH-responsive amphiphilic macromolecular carrier for doxorubicin delivery",
#                 "pub_year": "2017",
#                 "citation": "Journal of Bioactive and Compatible Polymers 32 (1), 3-16, 2017"
#             },
#             "filled": false,
#             "author_pub_id": "On_auewAAAAJ:UeHWp8X0CEIC",
#             "num_citations": 6,
#             "citedby_url": "https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1290479350068026837",
#             "cites_id": [
#                 "1290479350068026837"
#             ]
#         },
#         {
#             "container_type": "Publication",
#             "source": "AUTHOR_PUBLICATION_ENTRY",
#             "bib": {
#                 "title": "Proteomic Barcoding Platform for Macromolecular Screening and Delivery",
#                 "pub_year": "2024",
#                 "citation": "Journal of Proteome Research, 2024"
#             },
#             "filled": false,
#             "author_pub_id": "On_auewAAAAJ:_kc_bZDykSQC",
#             "num_citations": 0
#         }
#     ]
# }
# search_results <scholarly.publication_parser._SearchScholarIterator object at 0x7c7c1321b0d0>
#
#  ------
#
# Self-assembled cationic amphiphiles as antimicrobial peptides mimics: role of hydrophobicity, linkage type, and assembly state
# Citations: 120/130
# Link:  http://scholar.google.com/scholar?hl=en&cites=3025786761997466398&hl=en&scipsc=1&q=-author:%27Y%20Zhang%27+-author:%27A%20Algburi%27+-author:%27N%20Wang%27+-author:%27V%20Kholodovych%27+-author:%27D%20Oh%27+-author:%27M%20Chikindas%27+-author:%27K%20Uhrich%27
# search_results <scholarly.publication_parser._SearchScholarIterator object at 0x7c7beb296110>
#
#  ------
#
# The importance of N-heterocyclic carbene basicity in organocatalysis
# Citations: 75/75
# Link:  http://scholar.google.com/scholar?hl=en&cites=10296876123328836370&hl=en&scipsc=1&q=-author:%27J%20Wang%27+-author:%27J%20Xu%27
# search_results <scholarly.publication_parser._SearchScholarIterator object at 0x7c7beb297520>
#
#  ------
#
# Magnetic nanoparticles (MNPs) covalently coated by PEO–PPO–PEO block copolymer for drug delivery
# Citations: 72/74
# Link:  http://scholar.google.com/scholar?hl=en&cites=4886964103740525408&hl=en&scipsc=1&q=-author:%27N%20Wang%27+-author:%27Y%20Guan%27+-author:%27L%20Yang%27+-author:%27L%20Jia%27+-author:%27X%20Wei%27+-author:%27H%20Liu%27+-author:%27C%20Guo%27
# search_results <scholarly.publication_parser._SearchScholarIterator object at 0x7c7beb3fea10>
#
#  ------
#
# Synthesis of polyethylenimine modified Fe3O4 nanoparticles with immobilized Cu2+ for highly efficient proteins adsorption
# Citations: 50/60
# Link:  http://scholar.google.com/scholar?hl=en&cites=6146084551746983423&hl=en&scipsc=1&q=-author:%27T%20Xia%27+-author:%27Y%20Guan%27+-author:%27M%20Yang%27+-author:%27W%20Xiong%27+-author:%27N%20Wang%27+-author:%27S%20Zhao%27+-author:%27C%20Guo%27
# search_results <scholarly.publication_parser._SearchScholarIterator object at 0x7c7beb277940>
#
#  ------
#
# Light, middle, and heavy rare-earth group separation: a new approach via a liquid–liquid–liquid three-phase system
# Citations: 49/56
# Link:  http://scholar.google.com/scholar?hl=en&cites=14986652401149326093&hl=en&scipsc=1&q=-author:%27N%20Sui%27+-author:%27K%20Huang%27+-author:%27C%20Zhang%27+-author:%27N%20Wang%27+-author:%27F%20Wang%27+-author:%27H%20Liu%27
# search_results <scholarly.publication_parser._SearchScholarIterator object at 0x7c7beb2745e0>
#
#  ------
#
# Peroxidase-like activity of amino-functionalized magnetic nanoparticles and their applications in immunoassay
# Citations: 47/51
# Link:  http://scholar.google.com/scholar?hl=en&cites=17870898425588408596&hl=en&scipsc=1&q=-author:%27M%20Yang%27+-author:%27Y%20Guan%27+-author:%27Y%20Yang%27+-author:%27T%20Xia%27+-author:%27W%20Xiong%27+-author:%27N%20Wang%27+-author:%27C%20Guo%27
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-2e34b52e8cb4> in <cell line: 13>()
#      14     if not links_only:
#      15         # Sleep for some random time to mimic human behavior
# ---> 16         time.sleep(random.uniform(2, 5))
#      17
#      18     try:
#
# KeyboardInterrupt:
